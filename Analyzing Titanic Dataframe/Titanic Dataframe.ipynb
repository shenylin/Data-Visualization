# %%
# Analyzing Titanic Dataframe
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.keys()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
pd.pivot_table(df,index='Survived')
# it shows the means
# Out:
#                 Age       Fare     Parch  PassengerId    Pclass     SibSp
# Survived
# 0         30.626179  22.117887  0.329690   447.016393  2.531876  0.553734
# 1         28.343690  48.395408  0.464912   444.368421  1.950292  0.473684

# %%
pd.pivot_table(df,index='Sex')
# Out:
#               Age       Fare     Parch  PassengerId    Pclass     SibSp  \
# Sex
# female  27.915709  44.479818  0.649682   431.028662  2.159236  0.694268
# male    30.726645  25.523893  0.235702   454.147314  2.389948  0.429809
#
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
pd.pivot_table(df,index='Pclass')
# Out:
#               Age       Fare     Parch  PassengerId     SibSp  Survived
# Pclass
# 1       38.233441  84.154687  0.356481   461.597222  0.416667  0.629630
# 2       29.877630  20.662183  0.380435   445.956522  0.402174  0.472826
# 3       25.140620  13.675550  0.393075   439.154786  0.615071  0.242363

# %%
#What was the average survival rate?

# %%
df.keys()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Survived'].mean()
# Out:
# 0.3838383838383838

# %%
#How many people survived?

# %%
len(df[df['Survived'] == 1])
# Out:
# 342

# %%
sur_df = df.groupby('Survived').count()

plt.barh(sur_df['PassengerId'].index,sur_df['PassengerId'].values)
plt.ylabel('Survival of passengers')
plt.yticks(sur_df['PassengerId'].index, ['Died','Lived'])
plt.xlabel('Number of people (hundreds)')
# Out:
# Text(0.5, 0, 'Number of people (hundreds)')

# %%
#Members of what sex survived more?

# %%
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
sex_df = df.groupby(['Sex','Survived'], as_index=True).count()

width = 0.4
plt.barh(sex_df['PassengerId']['female'].index, sex_df['PassengerId']['female'].values, width, label='Women', color='pink')
plt.barh(sex_df['PassengerId']['male'].index + width, sex_df['PassengerId']['male'].values, width, label='Men', color='blue')
plt.ylabel('Survival of passengers by sex')
plt.yticks(sex_df['PassengerId']['female'].index, ['Died', 'Lived'])
plt.xlabel('Number of people (hundreds)')
plt.legend()

# %%
sex_df.index
# Out:
# MultiIndex([('female', 0),
#             ('female', 1),
#             (  'male', 0),
#             (  'male', 1)],
#            names=['Sex', 'Survived'])

# %%
#Did class membership affect survival rates?

# %%
df.groupby('Pclass').mean()
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
class_df = df.groupby('Pclass').mean()

plt.barh(class_df.index, class_df['Survived'].values)
plt.ylabel('Survival of passengers by class')
plt.yticks(class_df.index, ['First','Second','Third'])
plt.xlabel('mean')
plt.xticks(np.arange(0.0,0.7,0.1), ['0%','10%','20%','30%','40%','50%','60%'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fd8ab123f10>,
# ...
#  [Text(0, 0, '0%'),
#   Text(0, 0, '10%'),
#   Text(0, 0, '20%'),
#   Text(0, 0, '30%'),
#   Text(0, 0, '40%'),
#   Text(0, 0, '50%'),
#   Text(0, 0, '60%')])
